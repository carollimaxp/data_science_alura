# %% [markdown]
# <a href="https://colab.research.google.com/github/carollimaxp/data_science_alura/blob/main/DS_Bootcamp%20-%20Desafios%201%20e%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DS Bootcamp - Atividade

# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/drive/MyDrive/Data Scienc Bootcamp/A160324189_28_143_208.csv", 
                    encoding="ISO-8859-1", 
                    skiprows = 3,
                    delimiter=";",
                    skipfooter = 12,
                    thousands=".",
                    decimal=",")
                    #na_values = "-")
dados.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   import sys
#   Unidade da Federação 1992/Mar 1992/Abr  ...    2020/Jul     2020/Ago         Total
# 0          11 Rondônia        -        -  ...  7407388.24   3556381.57  929129659.72
# 1              12 Acre        -        -  ...  1163813.08            -  420668039.63
# 2          13 Amazonas        -        -  ... 13358514.02   4726485.73 1771654871.23
# 3           14 Roraima        -        -  ...  2739498.41   1524478.04  305010883.18
# 4              15 Pará        -        -  ... 27618727.51  11559714.54 4437115730.71
#
# [5 rows x 280 columns]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados['2020/Ago']
# Out:
# 0       3556381.57
# 1                -
# 2       4726485.73
# 3       1524478.04
# 4      11559714.54
# 5        834187.31
# 6       2453362.74
# 7      10916718.78
# 8       7926321.69
# 9      14559529.59
# 10      8080160.97
# 11      8585226.08
# 12     33544876.14
# 13      6487947.82
# 14      1742127.72
# 15     26023558.53
# 16     57473699.06
# 17     10824255.26
# 18     36264322.65
# 19    140414944.95
# 20     41542401.16
# 21     16991236.43
# 22     28349257.38
# 23      4059220.22
# 24      6174224.99
# 25     20242641.73
# 26     12044848.02
# Name: 2020/Ago, dtype: object

# %%
dados['2008/Ago'][0:11]
# Out:
# 0     2938286.29
# 1     1886871.84
# 2     8331763.97
# 3     1045291.11
# 4    23259148.28
# 5     1550340.63
# 6     5213290.38
# 7    14609872.57
# 8    10645917.52
# 9    29304821.51
# 10   10812840.19
# Name: 2008/Ago, dtype: float64

# %%
dados.mean()['2008/Ago']
# Out:
# 26636409.892222222

# %%
dados['2008/Ago'].mean()
# Out:
# 26636409.892222222

# %%
dados[["2020/Jul", "2020/Ago"]].head
# Out:
# <bound method NDFrame.head of        2020/Jul      2020/Ago
# 0    7407388.24    3556381.57
# 1    1163813.08             -
# 2   13358514.02    4726485.73
# 3    2739498.41    1524478.04
# 4   27618727.51   11559714.54
# 5    2155083.37     834187.31
# 6    4489665.87    2453362.74
# 7   24374205.15   10916718.78
# 8   18019214.49    7926321.69
# 9   30809221.22   14559529.59
# 10  19593057.45    8080160.97
# 11  15491469.06    8585226.08
# 12  62325444.34   33544876.14
# 13  13087850.40    6487947.82
# 14   3312766.32    1742127.72
# 15  58898100.40   26023558.53
# 16 120467187.34   57473699.06
# 17  27460475.47   10824255.26
# 18  71540227.33   36264322.65
# 19 282709570.31  140414944.95
# 20  80320852.69   41542401.16
# 21  51764534.76   16991236.43
# 22  78929703.81   28349257.38
# 23  12508717.35    4059220.22
# 24  13083151.70    6174224.99
# 25  33499284.38   20242641.73
# 26  22233542.26   12044848.02>

# %%
colunas_usaveis = dados.mean().index.to_list()
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  ...    2020/Jul         Total
# 0          11 Rondônia   4209.37  ...  7407388.24  929129659.72
# 1              12 Acre  10470.07  ...  1163813.08  420668039.63
# 2          13 Amazonas  35752.72  ... 13358514.02 1771654871.23
# 3           14 Roraima   4785.91  ...  2739498.41  305010883.18
# 4              15 Pará 181159.29  ... 27618727.51 4437115730.71
#
# [5 rows x 158 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jul          Total
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   7407388.24   929129659.72
# 12 Acre                  10470.07   14001.71  ...   1163813.08   420668039.63
# 13 Amazonas              35752.72   45570.64  ...  13358514.02  1771654871.23
# 14 Roraima                4785.91   11858.63  ...   2739498.41   305010883.18
# 15 Pará                 181159.29  433414.74  ...  27618727.51  4437115730.71
# 16 Amapá                 33672.74  104822.98  ...   2155083.37   291637984.75
# 17 Tocantins              4113.76   76633.06  ...   4489665.87   999998621.85
# 21 Maranhão             385330.18 1018352.93  ...  24374205.15  3632860959.84
# 22 Piauí                220788.25  353468.67  ...  18019214.49  2130616492.35
# 23 Ceará                357904.65  572356.18  ...  30809221.22  6197357245.98
# ...

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis = usaveis.drop("Total", axis=1)

# %%
usaveis
# Out:
#                          2007/Ago   2007/Set  ...     2020/Jun     2020/Jul
# Unidade da Federação                          ...
# 11 Rondônia               4209.37   16397.03  ...   9193593.76   7407388.24
# 12 Acre                  10470.07   14001.71  ...   2199920.70   1163813.08
# 13 Amazonas              35752.72   45570.64  ...  17509334.66  13358514.02
# 14 Roraima                4785.91   11858.63  ...   3216466.51   2739498.41
# 15 Pará                 181159.29  433414.74  ...  35396030.78  27618727.51
# 16 Amapá                 33672.74  104822.98  ...   2699492.23   2155083.37
# 17 Tocantins              4113.76   76633.06  ...   5018138.13   4489665.87
# 21 Maranhão             385330.18 1018352.93  ...  31128144.66  24374205.15
# 22 Piauí                220788.25  353468.67  ...  15375523.59  18019214.49
# 23 Ceará                357904.65  572356.18  ...  42146555.81  30809221.22
# 24 Rio Grande do Norte  134605.36  272088.08  ...  20219961.81  19593057.45
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


#controle dos eixos
ax = usaveis.sort_values(by="Unidade da Federação",axis=0).plot(y = '2020/Jun', kind = "bar", figsize = (25,6))

#ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.yaxis.set_major_formatter(ticker.EngFormatter())
plt.title("Média de Gastos com Produção Hospitalar pelo SUS por Local de Internações - Ago/2020")
plt.show()

# %%
from matplotlib.font_manager import FontProperties

ax = usaveis.T[{"50 Mato Grosso do Sul", "51 Mato Grosso", "52 Goiás", "53 Distrito Federal", "32 Espírito Santo"}].plot(figsize = (20,10))
#ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.yaxis.set_major_formatter(ticker.EngFormatter())
plt.legend(title='Unidades da Federação', bbox_to_anchor=(1.05, 1.01), loc='upper left')
plt.ylabel("Valor Gasto em Milhões")
plt.show()
